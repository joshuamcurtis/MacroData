# %%
import json
import pandas as pd
import requests
import sqlite3 as db
from sqlite3 import Error

# %run C:\Users\Joshua\Jupyter_Notebook_Folders\APIkeys.py

# %% [markdown]
# ### List of Bureau of Labor Statistics Surveys

# %%
surveys_url = "https://api.bls.gov/publicAPI/v2/surveys"
s = requests.get(surveys_url)
s_json = s.json()                          # Turn request into JSON 
surveys = s_json["Results"]["survey"]      # Get list of surveys from the JSON
surveys
# Out:
# [{'survey_abbreviation': 'AP',
#   'survey_name': 'Consumer Price Index - Average Price Data'},
#  {'survey_abbreviation': 'BD', 'survey_name': 'Business Employment Dynamics'},
#  {'survey_abbreviation': 'BG',
#   'survey_name': 'Collective Bargaining Agreements-State and Local Government'},
#  {'survey_abbreviation': 'BP',
#   'survey_name': 'Collective Bargaining Agreements-Private Sector'},
#  {'survey_abbreviation': 'CC',
#   'survey_name': 'Employer Costs for Employee Compensation'},
#  {'survey_abbreviation': 'CD',
#   'survey_name': 'Nonfatal cases involving days away from work: selected characteristics'},
#  {'survey_abbreviation': 'CE',
#   'survey_name': 'Employment, Hours, and Earnings from the Current Employment Statistics survey (National)'},
#  {'survey_abbreviation': 'CF',
#   'survey_name': 'Census of Fatal Occupational Injuries'},
#  {'survey_abbreviation': 'CH',
#   'survey_name': 'Nonfatal cases involving days away from work: selected characteristics (2003 - 2010)'},
#  {'survey_abbreviation': 'CI', 'survey_name': 'Employment Cost Index'},
#  {'survey_abbreviation': 'CM',
#   'survey_name': 'Employer Costs for Employee Compensation'},
#  {'survey_abbreviation': 'CS',
#   'survey_name': 'Nonfatal cases involving days away from work: selected characteristics (2011 forward)'},
#  {'survey_abbreviation': 'CU',
#   'survey_name': 'Consumer Price Index - All Urban Consumers'},
#  {'survey_abbreviation': 'CW',
#   'survey_name': 'Consumer Price Index - Urban Wage Earners and Clerical Workers'},
#  {'survey_abbreviation': 'CX', 'survey_name': 'Consumer Expenditure Survey'},
#  {'survey_abbreviation': 'EB', 'survey_name': 'Employee Benefits Survey'},
#  {'survey_abbreviation': 'EC', 'survey_name': 'Employment Cost Index'},
#  {'survey_abbreviation': 'EE',
#   'survey_name': 'National Employment, Hours, and Earnings'},
#  {'survey_abbreviation': 'EI', 'survey_name': 'Import/Export Price Indexes'},
#  {'survey_abbreviation': 'EN',
#   'survey_name': 'Quarterly Census of Employment and Wages'},
#  {'survey_abbreviation': 'EP',
#   'survey_name': 'Employment Projections by Industry'},
#  {'survey_abbreviation': 'EW',
#   'survey_name': 'Quarterly Census of Employment and Wages (SIC)'},
#  {'survey_abbreviation': 'FI',
#   'survey_name': 'Census of Fatal Occupational Injuries (2003 - 2010)'},
#  {'survey_abbreviation': 'FM',
#   'survey_name': 'Marital and family labor force statistics from the Current Population Survey'},
#  {'survey_abbreviation': 'FW',
#   'survey_name': 'Census of Fatal Occupational Injuries (2011 forward)'},
#  {'survey_abbreviation': 'GG', 'survey_name': 'Green Goods and Services'},
#  {'survey_abbreviation': 'GP', 'survey_name': 'Geographic Profile'},
#  {'survey_abbreviation': 'HC',
#   'survey_name': 'Nonfatal cases involving days away from work: Selected Characteristics (2002)'},
#  {'survey_abbreviation': 'HS',
#   'survey_name': 'Occupational injuries and illnesses: industry data (pre-1989)'},
#  {'survey_abbreviation': 'II',
#   'survey_name': 'Occupational injuries and illnesses: industry data'},
#  {'survey_abbreviation': 'IN',
#   'survey_name': 'International Labor Comparison'},
#  {'survey_abbreviation': 'IP', 'survey_name': 'Industry Productivity'},
#  {'survey_abbreviation': 'IS',
#   'survey_name': 'Occupational injuries and illnesses industry data'},
#  {'survey_abbreviation': 'JL',
#   'survey_name': 'Job Openings and Labor Turnover Survey'},
#  {'survey_abbreviation': 'JT',
#   'survey_name': 'Job Openings and Labor Turnover Survey'},
#  {'survey_abbreviation': 'LA',
#   'survey_name': 'Local Area Unemployment Statistics'},
#  {'survey_abbreviation': 'LE',
#   'survey_name': 'Weekly and hourly earnings data from the Current Population Survey'},
#  {'survey_abbreviation': 'LF',
#   'survey_name': 'Labor Force Statistics from the Current Population Survey (SIC)'},
#  {'survey_abbreviation': 'LI',
#   'survey_name': 'Consumer Price Index - Department Store Inventory Price Index'},
#  {'survey_abbreviation': 'LN',
#   'survey_name': 'Labor Force Statistics from the Current Population Survey'},
#  {'survey_abbreviation': 'LU',
#   'survey_name': 'Union affiliation data from the Current Population Survey'},
#  {'survey_abbreviation': 'ML', 'survey_name': 'Mass Layoff Statistics'},
#  {'survey_abbreviation': 'MP',
#   'survey_name': 'Major Sector Multifactor Productivity'},
#  {'survey_abbreviation': 'MU',
#   'survey_name': 'Consumer Price Index - All Urban Consumers (Old Series)'},
#  {'survey_abbreviation': 'MW',
#   'survey_name': 'Consumer Price Index - Urban Wage Earners and Clerical Workers (Old Series)'},
#  {'survey_abbreviation': 'NB',
#   'survey_name': 'National Compensation Survey-Benefits'},
#  {'survey_abbreviation': 'NC', 'survey_name': 'National Compensation Survey'},
#  {'survey_abbreviation': 'ND',
#   'survey_name': 'Producer Price Index Industry Data'},
#  {'survey_abbreviation': 'NW', 'survey_name': 'National Compensation Survey'},
#  {'survey_abbreviation': 'OE',
#   'survey_name': 'Occupational Employment Statistics'},
#  {'survey_abbreviation': 'OR', 'survey_name': 'Occupational Requirements'},
#  {'survey_abbreviation': 'PC',
#   'survey_name': 'Producer Price Index Industry Data'},
#  {'survey_abbreviation': 'PD',
#   'survey_name': 'Producer Price Index - Discontinued (SIC)'},
#  {'survey_abbreviation': 'PF',
#   'survey_name': 'Federal Government Productivity Index'},
#  {'survey_abbreviation': 'PI', 'survey_name': 'Industry Productivity Index'},
#  {'survey_abbreviation': 'PR',
#   'survey_name': 'Major Sector Productivity and Costs'},
#  {'survey_abbreviation': 'SA',
#   'survey_name': 'State and Area Employment, Hours, and Earnings (SIC)'},
#  {'survey_abbreviation': 'SH',
#   'survey_name': 'Occupational injuries and illnesses: industry data (1989-2001)'},
#  {'survey_abbreviation': 'SI',
#   'survey_name': 'Occupational injuries and illnesses: industry data (2002)'},
#  {'survey_abbreviation': 'SM',
#   'survey_name': 'State and Area Employment, Hours, and Earnings'},
#  {'survey_abbreviation': 'SU',
#   'survey_name': 'Consumer Price Index - Chained Consumer Price Index'},
#  {'survey_abbreviation': 'TU', 'survey_name': 'American Time Use'},
#  {'survey_abbreviation': 'WD',
#   'survey_name': 'Producer Price Index Commodity-Discontinued Series'},
#  {'survey_abbreviation': 'WM', 'survey_name': 'Wage Modeling'},
#  {'survey_abbreviation': 'WP',
#   'survey_name': 'Producer Price Index-Commodities'},
#  {'survey_abbreviation': 'WS', 'survey_name': 'Work Stoppage Data'}]

# %% [markdown]
# ### Get data from BLS

# %%
base_url = 'https://api.bls.gov/publicAPI/v2/timeseries/data/'  #this will not change
headers = {'Content-type': 'application/json'}  #This will not changed !

# For the key seriesid enter a list of series names you wish to download
# For the key startyear enter the start year inside ""
# For the key endyear enter the end year inside ""

seriesID = "CUUR0000SA0"
parameters = {
    "seriesid":[seriesID], 
    "startyear":"1919", 
    "endyear":"1938",
    "catalog":True, 
    "calculations":False, 
    "annualaverage":False,
    "aspects":False,
    "registrationkey":os.environ['BLS_API_key'] 
 }

data = json.dumps(parameters) # Converts the Python dictionary to JSON

p = requests.post(base_url, data=data, headers=headers)
json_data = json.loads(p.text)
json_data
# Out:
# {'status': 'REQUEST_SUCCEEDED',
#  'responseTime': 392,
#  'message': [],
#  'Results': {'series': [{'seriesID': 'CUUR0000SA0',
#     'catalog': {'series_title': 'All items in U.S. city average, all urban consumers, not seasonally adjusted',
#      'series_id': 'CUUR0000SA0',
#      'seasonality': 'Not Seasonally Adjusted',
#      'survey_name': 'CPI for All Urban Consumers (CPI-U)',
#      'survey_abbreviation': 'CU',
#      'measure_data_type': 'All items',
#      'area': 'U.S. city average',
#      'item': 'All items'},
#     'data': [{'year': '1938',
#       'period': 'M12',
#       'periodName': 'December',
#       'value': '14.0',
#       'footnotes': [{}]},
#      {'year': '1938',
#       'period': 'M11',
#       'periodName': 'November',
#       'value': '14.0',
#       'footnotes': [{}]},
#      {'year': '1938',
#       'period': 'M10',
#       'periodName': 'October',
#       'value': '14.0',
#       'footnotes': [{}]},
#      {'year': '1938',
#       'period': 'M09',
#       'periodName': 'September',
#       'value': '14.1',
#       'footnotes': [{}]},
#      {'year': '1938',
#       'period': 'M08',
#       'periodName': 'August',
#       'value': '14.1',
#       'footnotes': [{}]},
#      {'year': '1938',
#       'period': 'M07',
#       'periodName': 'July',
#       'value': '14.1',
#       'footnotes': [{}]},
#      {'year': '1938',
#       'period': 'M06',
#       'periodName': 'June',
#       'value': '14.1',
#       'footnotes': [{}]},
#      {'year': '1938',
#       'period': 'M05',
#       'periodName': 'May',
#       'value': '14.1',
#       'footnotes': [{}]},
#      {'year': '1938',
#       'period': 'M04',
#       'periodName': 'April',
#       'value': '14.2',
#       'footnotes': [{}]},
#      {'year': '1938',
#       'period': 'M03',
#       'periodName': 'March',
#       'value': '14.1',
#       'footnotes': [{}]},
#      {'year': '1938',
#       'period': 'M02',
#       'periodName': 'February',
#       'value': '14.1',
#       'footnotes': [{}]},
#      {'year': '1938',
#       'period': 'M01',
#       'periodName': 'January',
#       'value': '14.2',
#       'footnotes': [{}]},
#      {'year': '1937',
#       'period': 'M12',
#       'periodName': 'December',
#       'value': '14.4',
#       'footnotes': [{}]},
#      {'year': '1937',
#       'period': 'M11',
#       'periodName': 'November',
#       'value': '14.5',
#       'footnotes': [{}]},
#      {'year': '1937',
#       'period': 'M10',
#       'periodName': 'October',
#       'value': '14.6',
#       'footnotes': [{}]},
#      {'year': '1937',
#       'period': 'M09',
#       'periodName': 'September',
#       'value': '14.6',
#       'footnotes': [{}]},
#      {'year': '1937',
#       'period': 'M08',
#       'periodName': 'August',
#       'value': '14.5',
#       'footnotes': [{}]},
#      {'year': '1937',
#       'period': 'M07',
#       'periodName': 'July',
#       'value': '14.5',
#       'footnotes': [{}]},
#      {'year': '1937',
#       'period': 'M06',
#       'periodName': 'June',
#       'value': '14.4',
#       'footnotes': [{}]},
#      {'year': '1937',
#       'period': 'M05',
#       'periodName': 'May',
#       'value': '14.4',
#       'footnotes': [{}]},
#      {'year': '1937',
#       'period': 'M04',
#       'periodName': 'April',
#       'value': '14.3',
#       'footnotes': [{}]},
#      {'year': '1937',
#       'period': 'M03',
#       'periodName': 'March',
#       'value': '14.2',
#       'footnotes': [{}]},
#      {'year': '1937',
#       'period': 'M02',
#       'periodName': 'February',
#       'value': '14.1',
#       'footnotes': [{}]},
#      {'year': '1937',
#       'period': 'M01',
#       'periodName': 'January',
#       'value': '14.1',
#       'footnotes': [{}]},
#      {'year': '1936',
#       'period': 'M12',
#       'periodName': 'December',
#       'value': '14.0',
#       'footnotes': [{}]},
#      {'year': '1936',
#       'period': 'M11',
#       'periodName': 'November',
#       'value': '14.0',
#       'footnotes': [{}]},
#      {'year': '1936',
#       'period': 'M10',
#       'periodName': 'October',
#       'value': '14.0',
#       'footnotes': [{}]},
#      {'year': '1936',
#       'period': 'M09',
#       'periodName': 'September',
#       'value': '14.0',
#       'footnotes': [{}]},
#      {'year': '1936',
#       'period': 'M08',
#       'periodName': 'August',
#       'value': '14.0',
#       'footnotes': [{}]},
#      {'year': '1936',
#       'period': 'M07',
#       'periodName': 'July',
#       'value': '13.9',
#       'footnotes': [{}]},
#      {'year': '1936',
#       'period': 'M06',
#       'periodName': 'June',
#       'value': '13.8',
#       'footnotes': [{}]},
#      {'year': '1936',
#       'period': 'M05',
#       'periodName': 'May',
#       'value': '13.7',
#       'footnotes': [{}]},
#      {'year': '1936',
#       'period': 'M04',
#       'periodName': 'April',
#       'value': '13.7',
#       'footnotes': [{}]},
#      {'year': '1936',
#       'period': 'M03',
#       'periodName': 'March',
#       'value': '13.7',
#       'footnotes': [{}]},
#      {'year': '1936',
#       'period': 'M02',
#       'periodName': 'February',
#       'value': '13.8',
#       'footnotes': [{}]},
#      {'year': '1936',
#       'period': 'M01',
#       'periodName': 'January',
#       'value': '13.8',
#       'footnotes': [{}]},
#      {'year': '1935',
#       'period': 'M12',
#       'periodName': 'December',
#       'value': '13.8',
#       'footnotes': [{}]},
#      {'year': '1935',
#       'period': 'M11',
#       'periodName': 'November',
#       'value': '13.8',
#       'footnotes': [{}]},
#      {'year': '1935',
#       'period': 'M10',
#       'periodName': 'October',
#       'value': '13.7',
#       'footnotes': [{}]},
#      {'year': '1935',
#       'period': 'M09',
#       'periodName': 'September',
#       'value': '13.7',
#       'footnotes': [{}]},
#      {'year': '1935',
#       'period': 'M08',
#       'periodName': 'August',
#       'value': '13.7',
#       'footnotes': [{}]},
#      {'year': '1935',
#       'period': 'M07',
#       'periodName': 'July',
#       'value': '13.7',
#       'footnotes': [{}]},
#      {'year': '1935',
#       'period': 'M06',
#       'periodName': 'June',
#       'value': '13.7',
#       'footnotes': [{}]},
#      {'year': '1935',
#       'period': 'M05',
#       'periodName': 'May',
#       'value': '13.8',
#       'footnotes': [{}]},
#      {'year': '1935',
#       'period': 'M04',
#       'periodName': 'April',
#       'value': '13.8',
#       'footnotes': [{}]},
#      {'year': '1935',
#       'period': 'M03',
#       'periodName': 'March',
#       'value': '13.7',
#       'footnotes': [{}]},
#      {'year': '1935',
#       'period': 'M02',
#       'periodName': 'February',
#       'value': '13.7',
#       'footnotes': [{}]},
#      {'year': '1935',
#       'period': 'M01',
#       'periodName': 'January',
#       'value': '13.6',
#       'footnotes': [{}]},
#      {'year': '1934',
#       'period': 'M12',
#       'periodName': 'December',
#       'value': '13.4',
#       'footnotes': [{}]},
#      {'year': '1934',
#       'period': 'M11',
#       'periodName': 'November',
#       'value': '13.5',
#       'footnotes': [{}]},
#      {'year': '1934',
#       'period': 'M10',
#       'periodName': 'October',
#       'value': '13.5',
#       'footnotes': [{}]},
#      {'year': '1934',
#       'period': 'M09',
#       'periodName': 'September',
#       'value': '13.6',
#       'footnotes': [{}]},
#      {'year': '1934',
#       'period': 'M08',
#       'periodName': 'August',
#       'value': '13.4',
#       'footnotes': [{}]},
#      {'year': '1934',
#       'period': 'M07',
#       'periodName': 'July',
#       'value': '13.4',
#       'footnotes': [{}]},
#      {'year': '1934',
#       'period': 'M06',
#       'periodName': 'June',
#       'value': '13.4',
#       'footnotes': [{}]},
#      {'year': '1934',
#       'period': 'M05',
#       'periodName': 'May',
#       'value': '13.3',
#       'footnotes': [{}]},
#      {'year': '1934',
#       'period': 'M04',
#       'periodName': 'April',
#       'value': '13.3',
#       'footnotes': [{}]},
#      {'year': '1934',
#       'period': 'M03',
#       'periodName': 'March',
#       'value': '13.3',
#       'footnotes': [{}]},
#      {'year': '1934',
#       'period': 'M02',
#       'periodName': 'February',
#       'value': '13.3',
#       'footnotes': [{}]},
#      {'year': '1934',
#       'period': 'M01',
#       'periodName': 'January',
#       'value': '13.2',
#       'footnotes': [{}]},
#      {'year': '1933',
#       'period': 'M12',
#       'periodName': 'December',
#       'value': '13.2',
#       'footnotes': [{}]},
#      {'year': '1933',
#       'period': 'M11',
#       'periodName': 'November',
#       'value': '13.2',
#       'footnotes': [{}]},
#      {'year': '1933',
#       'period': 'M10',
#       'periodName': 'October',
#       'value': '13.2',
#       'footnotes': [{}]},
#      {'year': '1933',
#       'period': 'M09',
#       'periodName': 'September',
#       'value': '13.2',
#       'footnotes': [{}]},
#      {'year': '1933',
#       'period': 'M08',
#       'periodName': 'August',
#       'value': '13.2',
#       'footnotes': [{}]},
#      {'year': '1933',
#       'period': 'M07',
#       'periodName': 'July',
#       'value': '13.1',
#       'footnotes': [{}]},
#      {'year': '1933',
#       'period': 'M06',
#       'periodName': 'June',
#       'value': '12.7',
#       'footnotes': [{}]},
#      {'year': '1933',
#       'period': 'M05',
#       'periodName': 'May',
#       'value': '12.6',
#       'footnotes': [{}]},
#      {'year': '1933',
#       'period': 'M04',
#       'periodName': 'April',
#       'value': '12.6',
#       'footnotes': [{}]},
#      {'year': '1933',
#       'period': 'M03',
#       'periodName': 'March',
#       'value': '12.6',
#       'footnotes': [{}]},
#      {'year': '1933',
#       'period': 'M02',
#       'periodName': 'February',
#       'value': '12.7',
#       'footnotes': [{}]},
#      {'year': '1933',
#       'period': 'M01',
#       'periodName': 'January',
#       'value': '12.9',
#       'footnotes': [{}]},
#      {'year': '1932',
#       'period': 'M12',
#       'periodName': 'December',
#       'value': '13.1',
#       'footnotes': [{}]},
#      {'year': '1932',
#       'period': 'M11',
#       'periodName': 'November',
#       'value': '13.2',
#       'footnotes': [{}]},
#      {'year': '1932',
#       'period': 'M10',
#       'periodName': 'October',
#       'value': '13.3',
#       'footnotes': [{}]},
#      {'year': '1932',
#       'period': 'M09',
#       'periodName': 'September',
#       'value': '13.4',
#       'footnotes': [{}]},
#      {'year': '1932',
#       'period': 'M08',
#       'periodName': 'August',
#       'value': '13.5',
#       'footnotes': [{}]},
#      {'year': '1932',
#       'period': 'M07',
#       'periodName': 'July',
#       'value': '13.6',
#       'footnotes': [{}]},
#      {'year': '1932',
#       'period': 'M06',
#       'periodName': 'June',
#       'value': '13.6',
#       'footnotes': [{}]},
#      {'year': '1932',
#       'period': 'M05',
#       'periodName': 'May',
#       'value': '13.7',
#       'footnotes': [{}]},
#      {'year': '1932',
#       'period': 'M04',
#       'periodName': 'April',
#       'value': '13.9',
#       'footnotes': [{}]},
#      {'year': '1932',
#       'period': 'M03',
#       'periodName': 'March',
#       'value': '14.0',
#       'footnotes': [{}]},
#      {'year': '1932',
#       'period': 'M02',
#       'periodName': 'February',
#       'value': '14.1',
#       'footnotes': [{}]},
#      {'year': '1932',
#       'period': 'M01',
#       'periodName': 'January',
#       'value': '14.3',
#       'footnotes': [{}]},
#      {'year': '1931',
#       'period': 'M12',
#       'periodName': 'December',
#       'value': '14.6',
#       'footnotes': [{}]},
#      {'year': '1931',
#       'period': 'M11',
#       'periodName': 'November',
#       'value': '14.7',
#       'footnotes': [{}]},
#      {'year': '1931',
#       'period': 'M10',
#       'periodName': 'October',
#       'value': '14.9',
#       'footnotes': [{}]},
#      {'year': '1931',
#       'period': 'M09',
#       'periodName': 'September',
#       'value': '15.0',
#       'footnotes': [{}]},
#      {'year': '1931',
#       'period': 'M08',
#       'periodName': 'August',
#       'value': '15.1',
#       'footnotes': [{}]},
#      {'year': '1931',
#       'period': 'M07',
#       'periodName': 'July',
#       'value': '15.1',
#       'footnotes': [{}]},
#      {'year': '1931',
#       'period': 'M06',
#       'periodName': 'June',
#       'value': '15.1',
#       'footnotes': [{}]},
#      {'year': '1931',
#       'period': 'M05',
#       'periodName': 'May',
#       'value': '15.3',
#       'footnotes': [{}]},
#      {'year': '1931',
#       'period': 'M04',
#       'periodName': 'April',
#       'value': '15.5',
#       'footnotes': [{}]},
#      {'year': '1931',
#       'period': 'M03',
#       'periodName': 'March',
#       'value': '15.6',
#       'footnotes': [{}]},
#      {'year': '1931',
#       'period': 'M02',
#       'periodName': 'February',
#       'value': '15.7',
#       'footnotes': [{}]},
#      {'year': '1931',
#       'period': 'M01',
#       'periodName': 'January',
#       'value': '15.9',
#       'footnotes': [{}]},
#      {'year': '1930',
#       'period': 'M12',
#       'periodName': 'December',
#       'value': '16.1',
#       'footnotes': [{}]},
#      {'year': '1930',
#       'period': 'M11',
#       'periodName': 'November',
#       'value': '16.4',
#       'footnotes': [{}]},
#      {'year': '1930',
#       'period': 'M10',
#       'periodName': 'October',
#       'value': '16.5',
#       'footnotes': [{}]},
#      {'year': '1930',
#       'period': 'M09',
#       'periodName': 'September',
#       'value': '16.6',
#       'footnotes': [{}]},
#      {'year': '1930',
#       'period': 'M08',
#       'periodName': 'August',
#       'value': '16.5',
#       'footnotes': [{}]},
#      {'year': '1930',
#       'period': 'M07',
#       'periodName': 'July',
#       'value': '16.6',
#       'footnotes': [{}]},
#      {'year': '1930',
#       'period': 'M06',
#       'periodName': 'June',
#       'value': '16.8',
#       'footnotes': [{}]},
#      {'year': '1930',
#       'period': 'M05',
#       'periodName': 'May',
#       'value': '16.9',
#       'footnotes': [{}]},
#      {'year': '1930',
#       'period': 'M04',
#       'periodName': 'April',
#       'value': '17.0',
#       'footnotes': [{}]},
#      {'year': '1930',
#       'period': 'M03',
#       'periodName': 'March',
#       'value': '16.9',
#       'footnotes': [{}]},
#      {'year': '1930',
#       'period': 'M02',
#       'periodName': 'February',
#       'value': '17.0',
#       'footnotes': [{}]},
#      {'year': '1930',
#       'period': 'M01',
#       'periodName': 'January',
#       'value': '17.1',
#       'footnotes': [{}]},
#      {'year': '1929',
#       'period': 'M12',
#       'periodName': 'December',
#       'value': '17.2',
#       'footnotes': [{}]},
#      {'year': '1929',
#       'period': 'M11',
#       'periodName': 'November',
#       'value': '17.3',
#       'footnotes': [{}]},
#      {'year': '1929',
#       'period': 'M10',
#       'periodName': 'October',
#       'value': '17.3',
#       'footnotes': [{}]},
#      {'year': '1929',
#       'period': 'M09',
#       'periodName': 'September',
#       'value': '17.3',
#       'footnotes': [{}]},
#      {'year': '1929',
#       'period': 'M08',
#       'periodName': 'August',
#       'value': '17.3',
#       'footnotes': [{}]},
#      {'year': '1929',
#       'period': 'M07',
#       'periodName': 'July',
#       'value': '17.3',
#       'footnotes': [{}]},
#      {'year': '1929',
#       'period': 'M06',
#       'periodName': 'June',
#       'value': '17.1',
#       'footnotes': [{}]},
#      {'year': '1929',
#       'period': 'M05',
#       'periodName': 'May',
#       'value': '17.0',
#       'footnotes': [{}]},
#      {'year': '1929',
#       'period': 'M04',
#       'periodName': 'April',
#       'value': '16.9',
#       'footnotes': [{}]},
#      {'year': '1929',
#       'period': 'M03',
#       'periodName': 'March',
#       'value': '17.0',
#       'footnotes': [{}]},
#      {'year': '1929',
#       'period': 'M02',
#       'periodName': 'February',
#       'value': '17.1',
#       'footnotes': [{}]},
#      {'year': '1929',
#       'period': 'M01',
#       'periodName': 'January',
#       'value': '17.1',
#       'footnotes': [{}]},
#      {'year': '1928',
#       'period': 'M12',
#       'periodName': 'December',
#       'value': '17.1',
#       'footnotes': [{}]},
#      {'year': '1928',
#       'period': 'M11',
#       'periodName': 'November',
#       'value': '17.2',
#       'footnotes': [{}]},
#      {'year': '1928',
#       'period': 'M10',
#       'periodName': 'October',
#       'value': '17.2',
#       'footnotes': [{}]},
#      {'year': '1928',
#       'period': 'M09',
#       'periodName': 'September',
#       'value': '17.3',
#       'footnotes': [{}]},
#      {'year': '1928',
#       'period': 'M08',
#       'periodName': 'August',
#       'value': '17.1',
#       'footnotes': [{}]},
#      {'year': '1928',
#       'period': 'M07',
#       'periodName': 'July',
#       'value': '17.1',
#       'footnotes': [{}]},
#      {'year': '1928',
#       'period': 'M06',
#       'periodName': 'June',
#       'value': '17.1',
#       'footnotes': [{}]},
#      {'year': '1928',
#       'period': 'M05',
#       'periodName': 'May',
#       'value': '17.2',
#       'footnotes': [{}]},
#      {'year': '1928',
#       'period': 'M04',
#       'periodName': 'April',
#       'value': '17.1',
#       'footnotes': [{}]},
#      {'year': '1928',
#       'period': 'M03',
#       'periodName': 'March',
#       'value': '17.1',
#       'footnotes': [{}]},
#      {'year': '1928',
#       'period': 'M02',
#       'periodName': 'February',
#       'value': '17.1',
#       'footnotes': [{}]},
#      {'year': '1928',
#       'period': 'M01',
#       'periodName': 'January',
#       'value': '17.3',
#       'footnotes': [{}]},
#      {'year': '1927',
#       'period': 'M12',
#       'periodName': 'December',
#       'value': '17.3',
#       'footnotes': [{}]},
#      {'year': '1927',
#       'period': 'M11',
#       'periodName': 'November',
#       'value': '17.3',
#       'footnotes': [{}]},
#      {'year': '1927',
#       'period': 'M10',
#       'periodName': 'October',
#       'value': '17.4',
#       'footnotes': [{}]},
#      {'year': '1927',
#       'period': 'M09',
#       'periodName': 'September',
#       'value': '17.3',
#       'footnotes': [{}]},
#      {'year': '1927',
#       'period': 'M08',
#       'periodName': 'August',
#       'value': '17.2',
#       'footnotes': [{}]},
#      {'year': '1927',
#       'period': 'M07',
#       'periodName': 'July',
#       'value': '17.3',
#       'footnotes': [{}]},
#      {'year': '1927',
#       'period': 'M06',
#       'periodName': 'June',
#       'value': '17.6',
#       'footnotes': [{}]},
#      {'year': '1927',
#       'period': 'M05',
#       'periodName': 'May',
#       'value': '17.4',
#       'footnotes': [{}]},
#      {'year': '1927',
#       'period': 'M04',
#       'periodName': 'April',
#       'value': '17.3',
#       'footnotes': [{}]},
#      {'year': '1927',
#       'period': 'M03',
#       'periodName': 'March',
#       'value': '17.3',
#       'footnotes': [{}]},
#      {'year': '1927',
#       'period': 'M02',
#       'periodName': 'February',
#       'value': '17.4',
#       'footnotes': [{}]},
#      {'year': '1927',
#       'period': 'M01',
#       'periodName': 'January',
#       'value': '17.5',
#       'footnotes': [{}]},
#      {'year': '1926',
#       'period': 'M12',
#       'periodName': 'December',
#       'value': '17.7',
#       'footnotes': [{}]},
#      {'year': '1926',
#       'period': 'M11',
#       'periodName': 'November',
#       'value': '17.7',
#       'footnotes': [{}]},
#      {'year': '1926',
#       'period': 'M10',
#       'periodName': 'October',
#       'value': '17.6',
#       'footnotes': [{}]},
#      {'year': '1926',
#       'period': 'M09',
#       'periodName': 'September',
#       'value': '17.5',
#       'footnotes': [{}]},
#      {'year': '1926',
#       'period': 'M08',
#       'periodName': 'August',
#       'value': '17.4',
#       'footnotes': [{}]},
#      {'year': '1926',
#       'period': 'M07',
#       'periodName': 'July',
#       'value': '17.5',
#       'footnotes': [{}]},
#      {'year': '1926',
#       'period': 'M06',
#       'periodName': 'June',
#       'value': '17.7',
#       'footnotes': [{}]},
#      {'year': '1926',
#       'period': 'M05',
#       'periodName': 'May',
#       'value': '17.8',
#       'footnotes': [{}]},
#      {'year': '1926',
#       'period': 'M04',
#       'periodName': 'April',
#       'value': '17.9',
#       'footnotes': [{}]},
#      {'year': '1926',
#       'period': 'M03',
#       'periodName': 'March',
#       'value': '17.8',
#       'footnotes': [{}]},
#      {'year': '1926',
#       'period': 'M02',
#       'periodName': 'February',
#       'value': '17.9',
#       'footnotes': [{}]},
#      {'year': '1926',
#       'period': 'M01',
#       'periodName': 'January',
#       'value': '17.9',
#       'footnotes': [{}]},
#      {'year': '1925',
#       'period': 'M12',
#       'periodName': 'December',
#       'value': '17.9',
#       'footnotes': [{}]},
#      {'year': '1925',
#       'period': 'M11',
#       'periodName': 'November',
#       'value': '18.0',
#       'footnotes': [{}]},
#      {'year': '1925',
#       'period': 'M10',
#       'periodName': 'October',
#       'value': '17.7',
#       'footnotes': [{}]},
#      {'year': '1925',
#       'period': 'M09',
#       'periodName': 'September',
#       'value': '17.7',
#       'footnotes': [{}]},
#      {'year': '1925',
#       'period': 'M08',
#       'periodName': 'August',
#       'value': '17.7',
#       'footnotes': [{}]},
#      {'year': '1925',
#       'period': 'M07',
#       'periodName': 'July',
#       'value': '17.7',
#       'footnotes': [{}]},
#      {'year': '1925',
#       'period': 'M06',
#       'periodName': 'June',
#       'value': '17.5',
#       'footnotes': [{}]},
#      {'year': '1925',
#       'period': 'M05',
#       'periodName': 'May',
#       'value': '17.3',
#       'footnotes': [{}]},
#      {'year': '1925',
#       'period': 'M04',
#       'periodName': 'April',
#       'value': '17.2',
#       'footnotes': [{}]},
#      {'year': '1925',
#       'period': 'M03',
#       'periodName': 'March',
#       'value': '17.3',
#       'footnotes': [{}]},
#      {'year': '1925',
#       'period': 'M02',
#       'periodName': 'February',
#       'value': '17.2',
#       'footnotes': [{}]},
#      {'year': '1925',
#       'period': 'M01',
#       'periodName': 'January',
#       'value': '17.3',
#       'footnotes': [{}]},
#      {'year': '1924',
#       'period': 'M12',
#       'periodName': 'December',
#       'value': '17.3',
#       'footnotes': [{}]},
#      {'year': '1924',
#       'period': 'M11',
#       'periodName': 'November',
#       'value': '17.2',
#       'footnotes': [{}]},
#      {'year': '1924',
#       'period': 'M10',
#       'periodName': 'October',
#       'value': '17.2',
#       'footnotes': [{}]},
#      {'year': '1924',
#       'period': 'M09',
#       'periodName': 'September',
#       'value': '17.1',
#       'footnotes': [{}]},
#      {'year': '1924',
#       'period': 'M08',
#       'periodName': 'August',
#       'value': '17.0',
#       'footnotes': [{}]},
#      {'year': '1924',
#       'period': 'M07',
#       'periodName': 'July',
#       'value': '17.1',
#       'footnotes': [{}]},
#      {'year': '1924',
#       'period': 'M06',
#       'periodName': 'June',
#       'value': '17.0',
#       'footnotes': [{}]},
#      {'year': '1924',
#       'period': 'M05',
#       'periodName': 'May',
#       'value': '17.0',
#       'footnotes': [{}]},
#      {'year': '1924',
#       'period': 'M04',
#       'periodName': 'April',
#       'value': '17.0',
#       'footnotes': [{}]},
#      {'year': '1924',
#       'period': 'M03',
#       'periodName': 'March',
#       'value': '17.1',
#       'footnotes': [{}]},
#      {'year': '1924',
#       'period': 'M02',
#       'periodName': 'February',
#       'value': '17.2',
#       'footnotes': [{}]},
#      {'year': '1924',
#       'period': 'M01',
#       'periodName': 'January',
#       'value': '17.3',
#       'footnotes': [{}]},
#      {'year': '1923',
#       'period': 'M12',
#       'periodName': 'December',
#       'value': '17.3',
#       'footnotes': [{}]},
#      {'year': '1923',
#       'period': 'M11',
#       'periodName': 'November',
#       'value': '17.3',
#       'footnotes': [{}]},
#      {'year': '1923',
#       'period': 'M10',
#       'periodName': 'October',
#       'value': '17.3',
#       'footnotes': [{}]},
#      {'year': '1923',
#       'period': 'M09',
#       'periodName': 'September',
#       'value': '17.2',
#       'footnotes': [{}]},
#      {'year': '1923',
#       'period': 'M08',
#       'periodName': 'August',
#       'value': '17.1',
#       'footnotes': [{}]},
#      {'year': '1923',
#       'period': 'M07',
#       'periodName': 'July',
#       'value': '17.2',
#       'footnotes': [{}]},
#      {'year': '1923',
#       'period': 'M06',
#       'periodName': 'June',
#       'value': '17.0',
#       'footnotes': [{}]},
#      {'year': '1923',
#       'period': 'M05',
#       'periodName': 'May',
#       'value': '16.9',
#       'footnotes': [{}]},
#      {'year': '1923',
#       'period': 'M04',
#       'periodName': 'April',
#       'value': '16.9',
#       'footnotes': [{}]},
#      {'year': '1923',
#       'period': 'M03',
#       'periodName': 'March',
#       'value': '16.8',
#       'footnotes': [{}]},
#      {'year': '1923',
#       'period': 'M02',
#       'periodName': 'February',
#       'value': '16.8',
#       'footnotes': [{}]},
#      {'year': '1923',
#       'period': 'M01',
#       'periodName': 'January',
#       'value': '16.8',
#       'footnotes': [{}]},
#      {'year': '1922',
#       'period': 'M12',
#       'periodName': 'December',
#       'value': '16.9',
#       'footnotes': [{}]},
#      {'year': '1922',
#       'period': 'M11',
#       'periodName': 'November',
#       'value': '16.8',
#       'footnotes': [{}]},
#      {'year': '1922',
#       'period': 'M10',
#       'periodName': 'October',
#       'value': '16.7',
#       'footnotes': [{}]},
#      {'year': '1922',
#       'period': 'M09',
#       'periodName': 'September',
#       'value': '16.6',
#       'footnotes': [{}]},
#      {'year': '1922',
#       'period': 'M08',
#       'periodName': 'August',
#       'value': '16.6',
#       'footnotes': [{}]},
#      {'year': '1922',
#       'period': 'M07',
#       'periodName': 'July',
#       'value': '16.8',
#       'footnotes': [{}]},
#      {'year': '1922',
#       'period': 'M06',
#       'periodName': 'June',
#       'value': '16.7',
#       'footnotes': [{}]},
#      {'year': '1922',
#       'period': 'M05',
#       'periodName': 'May',
#       'value': '16.7',
#       'footnotes': [{}]},
#      {'year': '1922',
#       'period': 'M04',
#       'periodName': 'April',
#       'value': '16.7',
#       'footnotes': [{}]},
#      {'year': '1922',
#       'period': 'M03',
#       'periodName': 'March',
#       'value': '16.7',
#       'footnotes': [{}]},
#      {'year': '1922',
#       'period': 'M02',
#       'periodName': 'February',
#       'value': '16.9',
#       'footnotes': [{}]},
#      {'year': '1922',
#       'period': 'M01',
#       'periodName': 'January',
#       'value': '16.9',
#       'footnotes': [{}]},
#      {'year': '1921',
#       'period': 'M12',
#       'periodName': 'December',
#       'value': '17.3',
#       'footnotes': [{}]},
#      {'year': '1921',
#       'period': 'M11',
#       'periodName': 'November',
#       'value': '17.4',
#       'footnotes': [{}]},
#      {'year': '1921',
#       'period': 'M10',
#       'periodName': 'October',
#       'value': '17.5',
#       'footnotes': [{}]},
#      {'year': '1921',
#       'period': 'M09',
#       'periodName': 'September',
#       'value': '17.5',
#       'footnotes': [{}]},
#      {'year': '1921',
#       'period': 'M08',
#       'periodName': 'August',
#       'value': '17.7',
#       'footnotes': [{}]},
#      {'year': '1921',
#       'period': 'M07',
#       'periodName': 'July',
#       'value': '17.7',
#       'footnotes': [{}]},
#      {'year': '1921',
#       'period': 'M06',
#       'periodName': 'June',
#       'value': '17.6',
#       'footnotes': [{}]},
#      {'year': '1921',
#       'period': 'M05',
#       'periodName': 'May',
#       'value': '17.7',
#       'footnotes': [{}]},
#      {'year': '1921',
#       'period': 'M04',
#       'periodName': 'April',
#       'value': '18.1',
#       'footnotes': [{}]},
#      {'year': '1921',
#       'period': 'M03',
#       'periodName': 'March',
#       'value': '18.3',
#       'footnotes': [{}]},
#      {'year': '1921',
#       'period': 'M02',
#       'periodName': 'February',
#       'value': '18.4',
#       'footnotes': [{}]},
#      {'year': '1921',
#       'period': 'M01',
#       'periodName': 'January',
#       'value': '19.0',
#       'footnotes': [{}]},
#      {'year': '1920',
#       'period': 'M12',
#       'periodName': 'December',
#       'value': '19.4',
#       'footnotes': [{}]},
#      {'year': '1920',
#       'period': 'M11',
#       'periodName': 'November',
#       'value': '19.8',
#       'footnotes': [{}]},
#      {'year': '1920',
#       'period': 'M10',
#       'periodName': 'October',
#       'value': '19.9',
#       'footnotes': [{}]},
#      {'year': '1920',
#       'period': 'M09',
#       'periodName': 'September',
#       'value': '20.0',
#       'footnotes': [{}]},
#      {'year': '1920',
#       'period': 'M08',
#       'periodName': 'August',
#       'value': '20.3',
#       'footnotes': [{}]},
#      {'year': '1920',
#       'period': 'M07',
#       'periodName': 'July',
#       'value': '20.8',
#       'footnotes': [{}]},
#      {'year': '1920',
#       'period': 'M06',
#       'periodName': 'June',
#       'value': '20.9',
#       'footnotes': [{}]},
#      {'year': '1920',
#       'period': 'M05',
#       'periodName': 'May',
#       'value': '20.6',
#       'footnotes': [{}]},
#      {'year': '1920',
#       'period': 'M04',
#       'periodName': 'April',
#       'value': '20.3',
#       'footnotes': [{}]},
#      {'year': '1920',
#       'period': 'M03',
#       'periodName': 'March',
#       'value': '19.7',
#       'footnotes': [{}]},
#      {'year': '1920',
#       'period': 'M02',
#       'periodName': 'February',
#       'value': '19.5',
#       'footnotes': [{}]},
#      {'year': '1920',
#       'period': 'M01',
#       'periodName': 'January',
#       'value': '19.3',
#       'footnotes': [{}]},
#      {'year': '1919',
#       'period': 'M12',
#       'periodName': 'December',
#       'value': '18.9',
#       'footnotes': [{}]},
#      {'year': '1919',
#       'period': 'M11',
#       'periodName': 'November',
#       'value': '18.5',
#       'footnotes': [{}]},
#      {'year': '1919',
#       'period': 'M10',
#       'periodName': 'October',
#       'value': '18.1',
#       'footnotes': [{}]},
#      {'year': '1919',
#       'period': 'M09',
#       'periodName': 'September',
#       'value': '17.8',
#       'footnotes': [{}]},
#      {'year': '1919',
#       'period': 'M08',
#       'periodName': 'August',
#       'value': '17.7',
#       'footnotes': [{}]},
#      {'year': '1919',
#       'period': 'M07',
#       'periodName': 'July',
#       'value': '17.4',
#       'footnotes': [{}]},
#      {'year': '1919',
#       'period': 'M06',
#       'periodName': 'June',
#       'value': '16.9',
#       'footnotes': [{}]},
#      {'year': '1919',
#       'period': 'M05',
#       'periodName': 'May',
#       'value': '16.9',
#       'footnotes': [{}]},
#      {'year': '1919',
#       'period': 'M04',
#       'periodName': 'April',
#       'value': '16.7',
#       'footnotes': [{}]},
#      {'year': '1919',
#       'period': 'M03',
#       'periodName': 'March',
#       'value': '16.4',
#       'footnotes': [{}]},
#      {'year': '1919',
#       'period': 'M02',
#       'periodName': 'February',
#       'value': '16.2',
#       'footnotes': [{}]},
#      {'year': '1919',
#       'period': 'M01',
#       'periodName': 'January',
#       'value': '16.5',
#       'footnotes': [{}]}]}]}}

# %% [markdown]
# ### Create Panda Dataframe

# %%
df = pd.DataFrame(json_data['Results']['series'][0]['data'])
df['date'] = df['year'] + df['period']
df['date'] = df['date'].str.replace('M', '-')
df['date'] = df['date'].astype('string')
df = df.sort_values(by=['date'])
df = df.drop(columns='footnotes')
df['value'] = df['value'].astype(float)
df['description'] = 'Consumer Price Index - All Urban Consumers - Not Seasonally Adjusted'
df
# Out:
#      year period periodName  value     date  \
# 239  1919    M01    January   16.5  1919-01
# 238  1919    M02   February   16.2  1919-02
# 237  1919    M03      March   16.4  1919-03
# 236  1919    M04      April   16.7  1919-04
# 235  1919    M05        May   16.9  1919-05
# ..    ...    ...        ...    ...      ...
# 4    1938    M08     August   14.1  1938-08
# 3    1938    M09  September   14.1  1938-09
# 2    1938    M10    October   14.0  1938-10
# 1    1938    M11   November   14.0  1938-11
# 0    1938    M12   December   14.0  1938-12
#
#                                            description
# 239  Consumer Price Index - All Urban Consumers - N...
# 238  Consumer Price Index - All Urban Consumers - N...
# 237  Consumer Price Index - All Urban Consumers - N...
# 236  Consumer Price Index - All Urban Consumers - N...
# 235  Consumer Price Index - All Urban Consumers - N...
# ..                                                 ...
# 4    Consumer Price Index - All Urban Consumers - N...
# 3    Consumer Price Index - All Urban Consumers - N...
# 2    Consumer Price Index - All Urban Consumers - N...
# 1    Consumer Price Index - All Urban Consumers - N...
# 0    Consumer Price Index - All Urban Consumers - N...
#
# [240 rows x 6 columns]

# %%
print(df.dtypes)
# Out:
# year            object
# period          object
# periodName      object
# value          float64
# date            string
# description     object
# dtype: object

# %% [markdown]
# ### Functions for working with SQLite

# %%
def create_database(db_name):
    """ 
    create an SQLite database
    """
    conn = None
    try:
        conn = db.connect(db_name)
        print(db.version)
    except Error as e:
        print(e)
    finally:
        conn.close()

            
def create_connection(db_name):
    """ 
    create a database connection to the SQLite database
        specified by db_name
    return: Connection object or None
    """
    conn = None
    try:
        conn = db.connect(db_name)
        return conn
    except Error as e:
        print(e)

    return conn


def create_table(tbl_name ,db_name):
    """
    check if table exists
    """
    conn = create_connection(db_name)
    c = conn.cursor()
    c.execute("SELECT name FROM sqlite_master WHERE type='table';")
    tables = c.fetchall()
    try: 
        df.to_sql(tbl_name, conn)
    except ValueError as e:
        print(e)
        print("Table was not added to the DB")
        c.execute("SELECT name FROM sqlite_master WHERE type='table';")
        print("Tables already in DB ", c.fetchall())
        c.execute("PRAGMA table_info(CUUR0000SA0);")
        print("Table ", tbl_name, "has columns: ", c.fetchall())
        
    conn.close()

# %% [markdown]
# ### Create MacroData DB if it does not exist

# %%
create_database(r"MacroData")
# Out:
# 2.6.0

# %% [markdown]
# ### Create table if it does not already exist

# %%
create_table(seriesID, 'MacroData')
# Out:
# Table 'CUUR0000SA0' already exists.
# Table was not added to the DB
# Tables already in DB  [('CUUR0000SA0',)]
# Table  CUUR0000SA0 has columns:  [(0, 'index', 'INTEGER', 0, None, 0), (1, 'year', 'TEXT', 0, None, 0), (2, 'period', 'TEXT', 0, None, 0), (3, 'periodName', 'TEXT', 0, None, 0), (4, 'value', 'REAL', 0, None, 0), (5, 'date', 'TEXT', 0, None, 0), (6, 'description', 'TEXT', 0, None, 0)]

# %% [markdown]
# ### Check if data already exists in series

# %%
conn = db.connect('MacroData')
c = conn.cursor()

df_AddDB = pd.DataFrame(columns = list(df.columns))

for i in range(len(df.index)):
    c.execute("SELECT date, value FROM " + seriesID + " WHERE date = ?;", (df.iloc[i]["date"],))
    queryOut = c.fetchall()
    if len(queryOut) == 0:
        df_AddDB = pd.concat([df_AddDB, df[i:i+1]])
    elif queryOut[0][1] == df.iloc[i]["value"]:
        print(seriesID, " data for ", df.iloc[i]["date"], " already exists with same value as API:", queryOut[0][1])
    elif queryOut[0][1] != df.ioc[i]["value"]:
        print(seriesID, " ", df.ioc[i]["date"], "DB DATA: ", queryOut[0][1], " DOES NOT MATCH API DATA: ", )
#.execute("SELECT date, value FROM " + seriesID + " WHERE date = 1800-01;")
#print(len(c.fetchall()))
conn.close()
df_AddDB
# Out:
# CUUR0000SA0  data for  1919-01  already exists with same value as API: 16.5
# CUUR0000SA0  data for  1919-02  already exists with same value as API: 16.2
# CUUR0000SA0  data for  1919-03  already exists with same value as API: 16.4
# CUUR0000SA0  data for  1919-04  already exists with same value as API: 16.7
# CUUR0000SA0  data for  1919-05  already exists with same value as API: 16.9
# CUUR0000SA0  data for  1919-06  already exists with same value as API: 16.9
# CUUR0000SA0  data for  1919-07  already exists with same value as API: 17.4
# CUUR0000SA0  data for  1919-08  already exists with same value as API: 17.7
# CUUR0000SA0  data for  1919-09  already exists with same value as API: 17.8
# CUUR0000SA0  data for  1919-10  already exists with same value as API: 18.1
# CUUR0000SA0  data for  1919-11  already exists with same value as API: 18.5
# CUUR0000SA0  data for  1919-12  already exists with same value as API: 18.9
# CUUR0000SA0  data for  1920-01  already exists with same value as API: 19.3
# CUUR0000SA0  data for  1920-02  already exists with same value as API: 19.5
# CUUR0000SA0  data for  1920-03  already exists with same value as API: 19.7
# CUUR0000SA0  data for  1920-04  already exists with same value as API: 20.3
# CUUR0000SA0  data for  1920-05  already exists with same value as API: 20.6
# CUUR0000SA0  data for  1920-06  already exists with same value as API: 20.9
# CUUR0000SA0  data for  1920-07  already exists with same value as API: 20.8
# CUUR0000SA0  data for  1920-08  already exists with same value as API: 20.3
# CUUR0000SA0  data for  1920-09  already exists with same value as API: 20.0
# CUUR0000SA0  data for  1920-10  already exists with same value as API: 19.9
# CUUR0000SA0  data for  1920-11  already exists with same value as API: 19.8
# CUUR0000SA0  data for  1920-12  already exists with same value as API: 19.4
# CUUR0000SA0  data for  1921-01  already exists with same value as API: 19.0
# CUUR0000SA0  data for  1921-02  already exists with same value as API: 18.4
# CUUR0000SA0  data for  1921-03  already exists with same value as API: 18.3
# CUUR0000SA0  data for  1921-04  already exists with same value as API: 18.1
# CUUR0000SA0  data for  1921-05  already exists with same value as API: 17.7
# CUUR0000SA0  data for  1921-06  already exists with same value as API: 17.6
# CUUR0000SA0  data for  1921-07  already exists with same value as API: 17.7
# CUUR0000SA0  data for  1921-08  already exists with same value as API: 17.7
# CUUR0000SA0  data for  1921-09  already exists with same value as API: 17.5
# CUUR0000SA0  data for  1921-10  already exists with same value as API: 17.5
# CUUR0000SA0  data for  1921-11  already exists with same value as API: 17.4
# CUUR0000SA0  data for  1921-12  already exists with same value as API: 17.3
# CUUR0000SA0  data for  1922-01  already exists with same value as API: 16.9
# CUUR0000SA0  data for  1922-02  already exists with same value as API: 16.9
# CUUR0000SA0  data for  1922-03  already exists with same value as API: 16.7
# CUUR0000SA0  data for  1922-04  already exists with same value as API: 16.7
# CUUR0000SA0  data for  1922-05  already exists with same value as API: 16.7
# CUUR0000SA0  data for  1922-06  already exists with same value as API: 16.7
# CUUR0000SA0  data for  1922-07  already exists with same value as API: 16.8
# CUUR0000SA0  data for  1922-08  already exists with same value as API: 16.6
# CUUR0000SA0  data for  1922-09  already exists with same value as API: 16.6
# CUUR0000SA0  data for  1922-10  already exists with same value as API: 16.7
# CUUR0000SA0  data for  1922-11  already exists with same value as API: 16.8
# CUUR0000SA0  data for  1922-12  already exists with same value as API: 16.9
# CUUR0000SA0  data for  1923-01  already exists with same value as API: 16.8
# CUUR0000SA0  data for  1923-02  already exists with same value as API: 16.8
# CUUR0000SA0  data for  1923-03  already exists with same value as API: 16.8
# CUUR0000SA0  data for  1923-04  already exists with same value as API: 16.9
# CUUR0000SA0  data for  1923-05  already exists with same value as API: 16.9
# CUUR0000SA0  data for  1923-06  already exists with same value as API: 17.0
# CUUR0000SA0  data for  1923-07  already exists with same value as API: 17.2
# CUUR0000SA0  data for  1923-08  already exists with same value as API: 17.1
# CUUR0000SA0  data for  1923-09  already exists with same value as API: 17.2
# CUUR0000SA0  data for  1923-10  already exists with same value as API: 17.3
# CUUR0000SA0  data for  1923-11  already exists with same value as API: 17.3
# CUUR0000SA0  data for  1923-12  already exists with same value as API: 17.3
# CUUR0000SA0  data for  1924-01  already exists with same value as API: 17.3
# CUUR0000SA0  data for  1924-02  already exists with same value as API: 17.2
# CUUR0000SA0  data for  1924-03  already exists with same value as API: 17.1
# CUUR0000SA0  data for  1924-04  already exists with same value as API: 17.0
# CUUR0000SA0  data for  1924-05  already exists with same value as API: 17.0
# CUUR0000SA0  data for  1924-06  already exists with same value as API: 17.0
# CUUR0000SA0  data for  1924-07  already exists with same value as API: 17.1
# CUUR0000SA0  data for  1924-08  already exists with same value as API: 17.0
# CUUR0000SA0  data for  1924-09  already exists with same value as API: 17.1
# CUUR0000SA0  data for  1924-10  already exists with same value as API: 17.2
# CUUR0000SA0  data for  1924-11  already exists with same value as API: 17.2
# CUUR0000SA0  data for  1924-12  already exists with same value as API: 17.3
# CUUR0000SA0  data for  1925-01  already exists with same value as API: 17.3
# CUUR0000SA0  data for  1925-02  already exists with same value as API: 17.2
# CUUR0000SA0  data for  1925-03  already exists with same value as API: 17.3
# CUUR0000SA0  data for  1925-04  already exists with same value as API: 17.2
# CUUR0000SA0  data for  1925-05  already exists with same value as API: 17.3
# CUUR0000SA0  data for  1925-06  already exists with same value as API: 17.5
# CUUR0000SA0  data for  1925-07  already exists with same value as API: 17.7
# CUUR0000SA0  data for  1925-08  already exists with same value as API: 17.7
# CUUR0000SA0  data for  1925-09  already exists with same value as API: 17.7
# CUUR0000SA0  data for  1925-10  already exists with same value as API: 17.7
# CUUR0000SA0  data for  1925-11  already exists with same value as API: 18.0
# CUUR0000SA0  data for  1925-12  already exists with same value as API: 17.9
# CUUR0000SA0  data for  1926-01  already exists with same value as API: 17.9
# CUUR0000SA0  data for  1926-02  already exists with same value as API: 17.9
# CUUR0000SA0  data for  1926-03  already exists with same value as API: 17.8
# CUUR0000SA0  data for  1926-04  already exists with same value as API: 17.9
# CUUR0000SA0  data for  1926-05  already exists with same value as API: 17.8
# CUUR0000SA0  data for  1926-06  already exists with same value as API: 17.7
# CUUR0000SA0  data for  1926-07  already exists with same value as API: 17.5
# CUUR0000SA0  data for  1926-08  already exists with same value as API: 17.4
# CUUR0000SA0  data for  1926-09  already exists with same value as API: 17.5
# CUUR0000SA0  data for  1926-10  already exists with same value as API: 17.6
# CUUR0000SA0  data for  1926-11  already exists with same value as API: 17.7
# CUUR0000SA0  data for  1926-12  already exists with same value as API: 17.7
# CUUR0000SA0  data for  1927-01  already exists with same value as API: 17.5
# CUUR0000SA0  data for  1927-02  already exists with same value as API: 17.4
# CUUR0000SA0  data for  1927-03  already exists with same value as API: 17.3
# CUUR0000SA0  data for  1927-04  already exists with same value as API: 17.3
# CUUR0000SA0  data for  1927-05  already exists with same value as API: 17.4
# CUUR0000SA0  data for  1927-06  already exists with same value as API: 17.6
# CUUR0000SA0  data for  1927-07  already exists with same value as API: 17.3
# CUUR0000SA0  data for  1927-08  already exists with same value as API: 17.2
# CUUR0000SA0  data for  1927-09  already exists with same value as API: 17.3
# CUUR0000SA0  data for  1927-10  already exists with same value as API: 17.4
# CUUR0000SA0  data for  1927-11  already exists with same value as API: 17.3
# CUUR0000SA0  data for  1927-12  already exists with same value as API: 17.3
# CUUR0000SA0  data for  1928-01  already exists with same value as API: 17.3
# CUUR0000SA0  data for  1928-02  already exists with same value as API: 17.1
# CUUR0000SA0  data for  1928-03  already exists with same value as API: 17.1
# CUUR0000SA0  data for  1928-04  already exists with same value as API: 17.1
# CUUR0000SA0  data for  1928-05  already exists with same value as API: 17.2
# CUUR0000SA0  data for  1928-06  already exists with same value as API: 17.1
# CUUR0000SA0  data for  1928-07  already exists with same value as API: 17.1
# CUUR0000SA0  data for  1928-08  already exists with same value as API: 17.1
# CUUR0000SA0  data for  1928-09  already exists with same value as API: 17.3
# CUUR0000SA0  data for  1928-10  already exists with same value as API: 17.2
# CUUR0000SA0  data for  1928-11  already exists with same value as API: 17.2
# CUUR0000SA0  data for  1928-12  already exists with same value as API: 17.1
# CUUR0000SA0  data for  1929-01  already exists with same value as API: 17.1
# CUUR0000SA0  data for  1929-02  already exists with same value as API: 17.1
# CUUR0000SA0  data for  1929-03  already exists with same value as API: 17.0
# CUUR0000SA0  data for  1929-04  already exists with same value as API: 16.9
# CUUR0000SA0  data for  1929-05  already exists with same value as API: 17.0
# CUUR0000SA0  data for  1929-06  already exists with same value as API: 17.1
# CUUR0000SA0  data for  1929-07  already exists with same value as API: 17.3
# CUUR0000SA0  data for  1929-08  already exists with same value as API: 17.3
# CUUR0000SA0  data for  1929-09  already exists with same value as API: 17.3
# CUUR0000SA0  data for  1929-10  already exists with same value as API: 17.3
# CUUR0000SA0  data for  1929-11  already exists with same value as API: 17.3
# CUUR0000SA0  data for  1929-12  already exists with same value as API: 17.2
# CUUR0000SA0  data for  1930-01  already exists with same value as API: 17.1
# CUUR0000SA0  data for  1930-02  already exists with same value as API: 17.0
# CUUR0000SA0  data for  1930-03  already exists with same value as API: 16.9
# CUUR0000SA0  data for  1930-04  already exists with same value as API: 17.0
# CUUR0000SA0  data for  1930-05  already exists with same value as API: 16.9
# CUUR0000SA0  data for  1930-06  already exists with same value as API: 16.8
# CUUR0000SA0  data for  1930-07  already exists with same value as API: 16.6
# CUUR0000SA0  data for  1930-08  already exists with same value as API: 16.5
# CUUR0000SA0  data for  1930-09  already exists with same value as API: 16.6
# CUUR0000SA0  data for  1930-10  already exists with same value as API: 16.5
# CUUR0000SA0  data for  1930-11  already exists with same value as API: 16.4
# CUUR0000SA0  data for  1930-12  already exists with same value as API: 16.1
# CUUR0000SA0  data for  1931-01  already exists with same value as API: 15.9
# CUUR0000SA0  data for  1931-02  already exists with same value as API: 15.7
# CUUR0000SA0  data for  1931-03  already exists with same value as API: 15.6
# CUUR0000SA0  data for  1931-04  already exists with same value as API: 15.5
# CUUR0000SA0  data for  1931-05  already exists with same value as API: 15.3
# CUUR0000SA0  data for  1931-06  already exists with same value as API: 15.1
# CUUR0000SA0  data for  1931-07  already exists with same value as API: 15.1
# CUUR0000SA0  data for  1931-08  already exists with same value as API: 15.1
# CUUR0000SA0  data for  1931-09  already exists with same value as API: 15.0
# CUUR0000SA0  data for  1931-10  already exists with same value as API: 14.9
# CUUR0000SA0  data for  1931-11  already exists with same value as API: 14.7
# CUUR0000SA0  data for  1931-12  already exists with same value as API: 14.6
# CUUR0000SA0  data for  1932-01  already exists with same value as API: 14.3
# CUUR0000SA0  data for  1932-02  already exists with same value as API: 14.1
# CUUR0000SA0  data for  1932-03  already exists with same value as API: 14.0
# CUUR0000SA0  data for  1932-04  already exists with same value as API: 13.9
# CUUR0000SA0  data for  1932-05  already exists with same value as API: 13.7
# CUUR0000SA0  data for  1932-06  already exists with same value as API: 13.6
# CUUR0000SA0  data for  1932-07  already exists with same value as API: 13.6
# CUUR0000SA0  data for  1932-08  already exists with same value as API: 13.5
# CUUR0000SA0  data for  1932-09  already exists with same value as API: 13.4
# CUUR0000SA0  data for  1932-10  already exists with same value as API: 13.3
# CUUR0000SA0  data for  1932-11  already exists with same value as API: 13.2
# CUUR0000SA0  data for  1932-12  already exists with same value as API: 13.1
# CUUR0000SA0  data for  1933-01  already exists with same value as API: 12.9
# CUUR0000SA0  data for  1933-02  already exists with same value as API: 12.7
# CUUR0000SA0  data for  1933-03  already exists with same value as API: 12.6
# CUUR0000SA0  data for  1933-04  already exists with same value as API: 12.6
# CUUR0000SA0  data for  1933-05  already exists with same value as API: 12.6
# CUUR0000SA0  data for  1933-06  already exists with same value as API: 12.7
# CUUR0000SA0  data for  1933-07  already exists with same value as API: 13.1
# CUUR0000SA0  data for  1933-08  already exists with same value as API: 13.2
# CUUR0000SA0  data for  1933-09  already exists with same value as API: 13.2
# CUUR0000SA0  data for  1933-10  already exists with same value as API: 13.2
# CUUR0000SA0  data for  1933-11  already exists with same value as API: 13.2
# CUUR0000SA0  data for  1933-12  already exists with same value as API: 13.2
# CUUR0000SA0  data for  1934-01  already exists with same value as API: 13.2
# CUUR0000SA0  data for  1934-02  already exists with same value as API: 13.3
# CUUR0000SA0  data for  1934-03  already exists with same value as API: 13.3
# CUUR0000SA0  data for  1934-04  already exists with same value as API: 13.3
# CUUR0000SA0  data for  1934-05  already exists with same value as API: 13.3
# CUUR0000SA0  data for  1934-06  already exists with same value as API: 13.4
# CUUR0000SA0  data for  1934-07  already exists with same value as API: 13.4
# CUUR0000SA0  data for  1934-08  already exists with same value as API: 13.4
# CUUR0000SA0  data for  1934-09  already exists with same value as API: 13.6
# CUUR0000SA0  data for  1934-10  already exists with same value as API: 13.5
# CUUR0000SA0  data for  1934-11  already exists with same value as API: 13.5
# CUUR0000SA0  data for  1934-12  already exists with same value as API: 13.4
# CUUR0000SA0  data for  1935-01  already exists with same value as API: 13.6
# CUUR0000SA0  data for  1935-02  already exists with same value as API: 13.7
# CUUR0000SA0  data for  1935-03  already exists with same value as API: 13.7
# CUUR0000SA0  data for  1935-04  already exists with same value as API: 13.8
# CUUR0000SA0  data for  1935-05  already exists with same value as API: 13.8
# CUUR0000SA0  data for  1935-06  already exists with same value as API: 13.7
# CUUR0000SA0  data for  1935-07  already exists with same value as API: 13.7
# CUUR0000SA0  data for  1935-08  already exists with same value as API: 13.7
# CUUR0000SA0  data for  1935-09  already exists with same value as API: 13.7
# CUUR0000SA0  data for  1935-10  already exists with same value as API: 13.7
# CUUR0000SA0  data for  1935-11  already exists with same value as API: 13.8
# CUUR0000SA0  data for  1935-12  already exists with same value as API: 13.8
# CUUR0000SA0  data for  1936-01  already exists with same value as API: 13.8
# CUUR0000SA0  data for  1936-02  already exists with same value as API: 13.8
# CUUR0000SA0  data for  1936-03  already exists with same value as API: 13.7
# CUUR0000SA0  data for  1936-04  already exists with same value as API: 13.7
# CUUR0000SA0  data for  1936-05  already exists with same value as API: 13.7
# CUUR0000SA0  data for  1936-06  already exists with same value as API: 13.8
# CUUR0000SA0  data for  1936-07  already exists with same value as API: 13.9
# CUUR0000SA0  data for  1936-08  already exists with same value as API: 14.0
# CUUR0000SA0  data for  1936-09  already exists with same value as API: 14.0
# CUUR0000SA0  data for  1936-10  already exists with same value as API: 14.0
# CUUR0000SA0  data for  1936-11  already exists with same value as API: 14.0
# CUUR0000SA0  data for  1936-12  already exists with same value as API: 14.0
# CUUR0000SA0  data for  1937-01  already exists with same value as API: 14.1
# CUUR0000SA0  data for  1937-02  already exists with same value as API: 14.1
# CUUR0000SA0  data for  1937-03  already exists with same value as API: 14.2
# CUUR0000SA0  data for  1937-04  already exists with same value as API: 14.3
# CUUR0000SA0  data for  1937-05  already exists with same value as API: 14.4
# CUUR0000SA0  data for  1937-06  already exists with same value as API: 14.4
# CUUR0000SA0  data for  1937-07  already exists with same value as API: 14.5
# CUUR0000SA0  data for  1937-08  already exists with same value as API: 14.5
# CUUR0000SA0  data for  1937-09  already exists with same value as API: 14.6
# CUUR0000SA0  data for  1937-10  already exists with same value as API: 14.6
# CUUR0000SA0  data for  1937-11  already exists with same value as API: 14.5
# CUUR0000SA0  data for  1937-12  already exists with same value as API: 14.4
# CUUR0000SA0  data for  1938-01  already exists with same value as API: 14.2
# CUUR0000SA0  data for  1938-02  already exists with same value as API: 14.1
# CUUR0000SA0  data for  1938-03  already exists with same value as API: 14.1
# CUUR0000SA0  data for  1938-04  already exists with same value as API: 14.2
# CUUR0000SA0  data for  1938-05  already exists with same value as API: 14.1
# CUUR0000SA0  data for  1938-06  already exists with same value as API: 14.1
# CUUR0000SA0  data for  1938-07  already exists with same value as API: 14.1
# CUUR0000SA0  data for  1938-08  already exists with same value as API: 14.1
# CUUR0000SA0  data for  1938-09  already exists with same value as API: 14.1
# CUUR0000SA0  data for  1938-10  already exists with same value as API: 14.0
# CUUR0000SA0  data for  1938-11  already exists with same value as API: 14.0
# CUUR0000SA0  data for  1938-12  already exists with same value as API: 14.0
# Empty DataFrame
# Columns: [year, period, periodName, value, date, description]
# Index: []

# %%
con = db.connect('MacroData')
c = con.cursor()
c.execute("DROP TABLE " + seriesID)
con.commit()
con.close()

# %% [markdown]
# ### Insert Dataframe into MacroData DB

# %%
con = db.connect('MacroData')
df.to_sql(name = seriesID, con)


con.close()
