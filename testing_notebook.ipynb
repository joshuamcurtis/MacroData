# %%
# %run C:\Users\Joshua\Jupyter_Notebook_Folders\MacroData\Add_Data_DB.ipynb
# Out:
# Do you want to see the duplicate data? Y/NN
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# File ~\AppData\Local\Temp\ipykernel_10300\74136156.py:19, in <cell line: 17>()
#      17 if check_table_exists(seriesID, db_name) != 0:
#      18     df = align_df_db_indexes(df, seriesID, db_name)
# ---> 19     add_to_database(df, seriesID, db_name, 'replace')
#      20 else:
#      21     add_to_database(df, seriesID, db_name, 'replace')
#
# File ~\AppData\Local\Temp\ipykernel_10300\2501158906.py:113, in add_to_database(df_EntryData, tbl_name, db_name, append_replace)
#     111 conn = create_connection(db_name)
#     112 try:
# --> 113     df_EntryData.to_sql(seriesID, con=conn, if_exists = append_replace)
#     114     print("Data added to DB: \n", df_EntryData)
#     115 except ValueError as e:
#
# File ~\anaconda3\lib\site-packages\pandas\core\generic.py:2951, in NDFrame.to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2794 """
#    2795 Write records stored in a DataFrame to a SQL database.
#    2796
#    (...)
#    2947 [(1,), (None,), (2,)]
#    2948 """  # noqa:E501
#    2949 from pandas.io import sql
# -> 2951 return sql.to_sql(
#    2952     self,
#    2953     name,
#    2954     con,
#    2955     schema=schema,
#    2956     if_exists=if_exists,
#    2957     index=index,
#    2958     index_label=index_label,
#    2959     chunksize=chunksize,
#    2960     dtype=dtype,
#    2961     method=method,
#    2962 )
#
# File ~\anaconda3\lib\site-packages\pandas\io\sql.py:697, in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method, engine, **engine_kwargs)
#     692 elif not isinstance(frame, DataFrame):
#     693     raise NotImplementedError(
#     694         "'frame' argument should be either a Series or a DataFrame"
#     695     )
# --> 697 return pandas_sql.to_sql(
#     698     frame,
#     699     name,
#     700     if_exists=if_exists,
#     701     index=index,
#     702     index_label=index_label,
#     703     schema=schema,
#     704     chunksize=chunksize,
#     705     dtype=dtype,
#     706     method=method,
#     707     engine=engine,
#     708     **engine_kwargs,
#     709 )
#
# File ~\anaconda3\lib\site-packages\pandas\io\sql.py:2189, in SQLiteDatabase.to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype, method, **kwargs)
#    2178             raise ValueError(f"{col} ({my_type}) not a string")
#    2180 table = SQLiteTable(
#    2181     name,
#    2182     self,
#    (...)
#    2187     dtype=dtype,
#    2188 )
# -> 2189 table.create()
#    2190 return table.insert(chunksize, method)
#
# File ~\anaconda3\lib\site-packages\pandas\io\sql.py:836, in SQLTable.create(self)
#     834 elif self.if_exists == "replace":
#     835     self.pd_sql.drop_table(self.name, self.schema)
# --> 836     self._execute_create()
#     837 elif self.if_exists == "append":
#     838     pass
#
# File ~\anaconda3\lib\site-packages\pandas\io\sql.py:1873, in SQLiteTable._execute_create(self)
#    1871 with self.pd_sql.run_transaction() as conn:
#    1872     for stmt in self.table:
# -> 1873         conn.execute(stmt)
#
# OperationalError: duplicate column name: level_0
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# Input In [3], in <cell line: 1>()
# ----> 1 get_ipython().run_line_magic('run', 'C:\\Users\\Joshua\\Jupyter_Notebook_Folders\\MacroData\\Add_Data_DB.ipynb')
#
# File ~\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2304, in InteractiveShell.run_line_magic(self, magic_name, line, _stack_depth)
#    2302     kwargs['local_ns'] = self.get_local_scope(stack_depth)
#    2303 with self.builtin_trap:
# -> 2304     result = fn(*args, **kwargs)
#    2305 return result
#
# File ~\anaconda3\lib\site-packages\IPython\core\magics\execution.py:717, in ExecutionMagics.run(self, parameter_s, runner, file_finder)
#     715     with preserve_keys(self.shell.user_ns, '__file__'):
#     716         self.shell.user_ns['__file__'] = filename
# --> 717         self.shell.safe_execfile_ipy(filename, raise_exceptions=True)
#     718     return
#     720 # Control the response to exit() calls made by the script being run
#
# File ~\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2810, in InteractiveShell.safe_execfile_ipy(self, fname, shell_futures, raise_exceptions)
#    2808 result = self.run_cell(cell, silent=True, shell_futures=shell_futures)
#    2809 if raise_exceptions:
# -> 2810     result.raise_error()
#    2811 elif not result.success:
#    2812     break
#
# File ~\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:250, in ExecutionResult.raise_error(self)
#     248     raise self.error_before_exec
#     249 if self.error_in_exec is not None:
# --> 250     raise self.error_in_exec
#
#     [... skipping hidden 1 frame]
#
# File ~\AppData\Local\Temp\ipykernel_10300\74136156.py:19, in <cell line: 17>()
#      17 if check_table_exists(seriesID, db_name) != 0:
#      18     df = align_df_db_indexes(df, seriesID, db_name)
# ---> 19     add_to_database(df, seriesID, db_name, 'replace')
#      20 else:
#      21     add_to_database(df, seriesID, db_name, 'replace')
#
# File ~\AppData\Local\Temp\ipykernel_10300\2501158906.py:113, in add_to_database(df_EntryData, tbl_name, db_name, append_replace)
#     111 conn = create_connection(db_name)
#     112 try:
# --> 113     df_EntryData.to_sql(seriesID, con=conn, if_exists = append_replace)
#     114     print("Data added to DB: \n", df_EntryData)
#     115 except ValueError as e:
#
# File ~\anaconda3\lib\site-packages\pandas\core\generic.py:2951, in NDFrame.to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2794 """
#    2795 Write records stored in a DataFrame to a SQL database.
#    2796
#    (...)
#    2947 [(1,), (None,), (2,)]
#    2948 """  # noqa:E501
#    2949 from pandas.io import sql
# -> 2951 return sql.to_sql(
#    2952     self,
#    2953     name,
#    2954     con,
#    2955     schema=schema,
#    2956     if_exists=if_exists,
#    2957     index=index,
#    2958     index_label=index_label,
#    2959     chunksize=chunksize,
#    2960     dtype=dtype,
#    2961     method=method,
#    2962 )
#
# File ~\anaconda3\lib\site-packages\pandas\io\sql.py:697, in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method, engine, **engine_kwargs)
#     692 elif not isinstance(frame, DataFrame):
#     693     raise NotImplementedError(
#     694         "'frame' argument should be either a Series or a DataFrame"
#     695     )
# --> 697 return pandas_sql.to_sql(
#     698     frame,
#     699     name,
#     700     if_exists=if_exists,
#     701     index=index,
#     702     index_label=index_label,
#     703     schema=schema,
#     704     chunksize=chunksize,
#     705     dtype=dtype,
#     706     method=method,
#     707     engine=engine,
#     708     **engine_kwargs,
#     709 )
#
# File ~\anaconda3\lib\site-packages\pandas\io\sql.py:2189, in SQLiteDatabase.to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype, method, **kwargs)
#    2178             raise ValueError(f"{col} ({my_type}) not a string")
#    2180 table = SQLiteTable(
#    2181     name,
#    2182     self,
#    (...)
#    2187     dtype=dtype,
#    2188 )
# -> 2189 table.create()
#    2190 return table.insert(chunksize, method)
#
# File ~\anaconda3\lib\site-packages\pandas\io\sql.py:836, in SQLTable.create(self)
#     834 elif self.if_exists == "replace":
#     835     self.pd_sql.drop_table(self.name, self.schema)
# --> 836     self._execute_create()
#     837 elif self.if_exists == "append":
#     838     pass
#
# File ~\anaconda3\lib\site-packages\pandas\io\sql.py:1873, in SQLiteTable._execute_create(self)
#    1871 with self.pd_sql.run_transaction() as conn:
#    1872     for stmt in self.table:
# -> 1873         conn.execute(stmt)
#
# OperationalError: duplicate column name: level_0

# %%
seriesID = "CUUR0000SA0"

# %%
message, json_data = get_BLS_data(seriesID, 1910, 1929)
message
# Out:
# 'For series CUUR0000SA0 no data for years: 1910, 1911, 1912, '

# %%
df = format_df_from_json(json_data, seriesID, "MacroData.sqlite3")

# %%
df
# Out:
# Empty DataFrame
# Columns: [year, period, periodName, value, date, description]
# Index: []

# %%
create_table(df, seriesID, 'MacroData.sqlite3')

# %%
df_AddDB, df_dup_data, df_inconsistent_data = check_duplicate_data(df, seriesID, 'MacroData.sqlite3')

# Deal with duplicate data
if not df_dup_data.empty:
    print("Duplicate Data: \n", df_dup_data)
else:
    del df_dup_data
    
# Deal with inconsistent data
if not df_inconsistent_data.empty:
    print("DATA FROM DATAFRAME DOES INCONSISTENT WITH DATA IN DATABASE: \n", df_inconsistent_data)
else:
    del df_inconsistent_data

df_AddDB
# Out:
# Duplicate Data:
#        year period periodName value     date  \
# 1032  1919    M01    January  16.5  1919-01
# 1033  1919    M02   February  16.2  1919-02
# 1034  1919    M03      March  16.4  1919-03
# 1035  1919    M04      April  16.7  1919-04
# 1036  1919    M05        May  16.9  1919-05
# ...    ...    ...        ...   ...      ...
# 1159  1929    M08     August  17.3  1929-08
# 1160  1929    M09  September  17.3  1929-09
# 1161  1929    M10    October  17.3  1929-10
# 1162  1929    M11   November  17.3  1929-11
# 1163  1929    M12   December  17.2  1929-12
#
#                                             description
# 1032  CPI for All Urban Consumers (CPI-U), All items...
# 1033  CPI for All Urban Consumers (CPI-U), All items...
# 1034  CPI for All Urban Consumers (CPI-U), All items...
# 1035  CPI for All Urban Consumers (CPI-U), All items...
# 1036  CPI for All Urban Consumers (CPI-U), All items...
# ...                                                 ...
# 1159  CPI for All Urban Consumers (CPI-U), All items...
# 1160  CPI for All Urban Consumers (CPI-U), All items...
# 1161  CPI for All Urban Consumers (CPI-U), All items...
# 1162  CPI for All Urban Consumers (CPI-U), All items...
# 1163  CPI for All Urban Consumers (CPI-U), All items...
#
# [132 rows x 6 columns]
#       year period periodName value     date  \
# 960   1913    M01    January   9.8  1913-01
# 961   1913    M02   February   9.8  1913-02
# 962   1913    M03      March   9.8  1913-03
# 963   1913    M04      April   9.8  1913-04
# 964   1913    M05        May   9.7  1913-05
# ...    ...    ...        ...   ...      ...
# 1027  1918    M08     August  15.4  1918-08
# 1028  1918    M09  September  15.7  1918-09
# 1029  1918    M10    October  16.0  1918-10
# 1030  1918    M11   November  16.3  1918-11
# 1031  1918    M12   December  16.5  1918-12
#
#                                             description
# 960   CPI for All Urban Consumers (CPI-U), All items...
# 961   CPI for All Urban Consumers (CPI-U), All items...
# 962   CPI for All Urban Consumers (CPI-U), All items...
# 963   CPI for All Urban Consumers (CPI-U), All items...
# 964   CPI for All Urban Consumers (CPI-U), All items...
# ...                                                 ...
# 1027  CPI for All Urban Consumers (CPI-U), All items...
# 1028  CPI for All Urban Consumers (CPI-U), All items...
# 1029  CPI for All Urban Consumers (CPI-U), All items...
# 1030  CPI for All Urban Consumers (CPI-U), All items...
# 1031  CPI for All Urban Consumers (CPI-U), All items...
#
# [72 rows x 6 columns]

# %%
add_to_database(df_AddDB, seriesID, 'MacroData.sqlite3')
# Out:
# Data added to DB:
#        year period periodName value     date  \
# 960   1913    M01    January   9.8  1913-01
# 961   1913    M02   February   9.8  1913-02
# 962   1913    M03      March   9.8  1913-03
# 963   1913    M04      April   9.8  1913-04
# 964   1913    M05        May   9.7  1913-05
# ...    ...    ...        ...   ...      ...
# 1027  1918    M08     August  15.4  1918-08
# 1028  1918    M09  September  15.7  1918-09
# 1029  1918    M10    October  16.0  1918-10
# 1030  1918    M11   November  16.3  1918-11
# 1031  1918    M12   December  16.5  1918-12
#
#                                             description
# 960   CPI for All Urban Consumers (CPI-U), All items...
# 961   CPI for All Urban Consumers (CPI-U), All items...
# 962   CPI for All Urban Consumers (CPI-U), All items...
# 963   CPI for All Urban Consumers (CPI-U), All items...
# 964   CPI for All Urban Consumers (CPI-U), All items...
# ...                                                 ...
# 1027  CPI for All Urban Consumers (CPI-U), All items...
# 1028  CPI for All Urban Consumers (CPI-U), All items...
# 1029  CPI for All Urban Consumers (CPI-U), All items...
# 1030  CPI for All Urban Consumers (CPI-U), All items...
# 1031  CPI for All Urban Consumers (CPI-U), All items...
#
# [72 rows x 6 columns]

# %%
df_cpi_not_seasonal = table_to_df(seriesID, 'MacroData.sqlite3')
df_cpi_not_seasonal
# Out:
#       index  year period periodName  value     date  \
# 0         0  1919    M01    January   16.5  1919-01
# 1         1  1919    M02   February   16.2  1919-02
# 2         2  1919    M03      March   16.4  1919-03
# 3         3  1919    M04      April   16.7  1919-04
# 4         4  1919    M05        May   16.9  1919-05
# ...     ...   ...    ...        ...    ...      ...
# 1027   1027  1918    M08     August   15.4  1918-08
# 1028   1028  1918    M09  September   15.7  1918-09
# 1029   1029  1918    M10    October   16.0  1918-10
# 1030   1030  1918    M11   November   16.3  1918-11
# 1031   1031  1918    M12   December   16.5  1918-12
#
#                                             description
# 0     CPI for All Urban Consumers (CPI-U), All items...
# 1     CPI for All Urban Consumers (CPI-U), All items...
# 2     CPI for All Urban Consumers (CPI-U), All items...
# 3     CPI for All Urban Consumers (CPI-U), All items...
# 4     CPI for All Urban Consumers (CPI-U), All items...
# ...                                                 ...
# 1027  CPI for All Urban Consumers (CPI-U), All items...
# 1028  CPI for All Urban Consumers (CPI-U), All items...
# 1029  CPI for All Urban Consumers (CPI-U), All items...
# 1030  CPI for All Urban Consumers (CPI-U), All items...
# 1031  CPI for All Urban Consumers (CPI-U), All items...
#
# [1032 rows x 7 columns]

# %%
con = db.connect('MacroData.sqlite3')
c = con.cursor()
c.execute("DROP TABLE " + seriesID)
con.commit()
con.close()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [2], in <cell line: 1>()
# ----> 1 con = db.connect('MacroData.sqlite3')
#       2 c = con.cursor()
#       3 c.execute("DROP TABLE " + seriesID)
#
# NameError: name 'db' is not defined
